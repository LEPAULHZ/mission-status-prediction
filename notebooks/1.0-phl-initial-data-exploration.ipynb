# %% [markdown]
# # Status Mission Prediction

# %% [markdown]
# ## 1. Problem Statement
#  This project aim to understand how the Status Mission is affected by other variables such as Company, Country, Ownership and many other possible variables to be discover.

# %% [markdown]
# ## 2. Data Collection
# * Data Source: https://www.kaggle.com/datasets/davidroberts13/one-small-step-for-data
# * Data Shape: 4324 rows X 15 columns

# %% [markdown]
# ## 2.1 Import Data and Packages

# %% [markdown]
# ### Import Pands, Numpy, Matplolib

# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import set_config
from datetime import datetime

# %% [markdown]
# ### Import CSV Data as Panda DataFrame

# %%
df = pd.read_csv('global_space_launches.csv')

# %% [markdown]
# #### Display Data

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1           CASIC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                                             Detail  Status Rocket  Rocket  \
# 0     Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive   50.0
# 1              Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive  29.75
# 2               Starship Prototype | 150 Meter Hop   StatusActive     NaN
# 3     Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive   65.0
# 4                       Atlas V 541 | Perseverance   StatusActive  145.0
# ...                                            ...            ...     ...
# 4319                     Vanguard | Vanguard TV3BU  StatusRetired     NaN
# 4320                           Juno I | Explorer 1  StatusRetired     NaN
# 4321                       Vanguard | Vanguard TV3  StatusRetired     NaN
# 4322                    Sputnik 8K71PS | Sputnik-2  StatusRetired     NaN
# 4323                    Sputnik 8K71PS | Sputnik-1  StatusRetired     NaN
#
#      Status Mission Country of Launch Companys Country of Origin  \
# 0           Success               USA                        USA
# 1           Success             China                      China
# 2           Success               USA                        USA
# 3           Success        Kazakhstan                     Russia
# 4           Success               USA                        USA
# ...             ...               ...                        ...
# 4319        Failure               USA                        USA
# 4320        Success               USA                        USA
# 4321        Failure               USA                        USA
# 4322        Success        Kazakhstan                     Russia
# 4323        Success        Kazakhstan                     Russia
#
#      Private or State Run                   DateTime  Year  Month  Day  \
# 0                       P  2020-08-07 05:12:00+00:00  2020      8    7
# 1                       S  2020-08-06 04:01:00+00:00  2020      8    6
# 2                       P  2020-08-04 23:57:00+00:00  2020      8    4
# 3                       S  2020-07-30 21:25:00+00:00  2020      7   30
# 4                       P  2020-07-30 11:50:00+00:00  2020      7   30
# ...                   ...                        ...   ...    ...  ...
# 4319                    S  1958-02-05 07:33:00+00:00  1958      2    5
# 4320                    S  1958-02-01 03:48:00+00:00  1958      2    1
# 4321                    S  1957-12-06 16:44:00+00:00  1957     12    6
# 4322                    S  1957-11-03 02:30:00+00:00  1957     11    3
# 4323                    S  1957-10-04 19:28:00+00:00  1957     10    4
#
#             Date   Time
# 0     07/08/2020  05:12
# 1     06/08/2020  04:01
# 2     04/08/2020  23:57
# 3     30/07/2020  21:25
# 4     30/07/2020  11:50
# ...          ...    ...
# 4319  05/02/1958  07:33
# 4320  01/02/1958  03:48
# 4321  06/12/1957  16:44
# 4322  03/11/1957  02:30
# 4323  04/10/1957  19:28
#
# [4324 rows x 15 columns]

# %% [markdown]
# ## 3. Data Checks to Perform
# * Columns Cleanliness & Readability
# * Check Missing Values
# * Check Duplicates
# * Check Data Type
# * Check Unique Values
# * Check Statistics
# * Check Categories

# %% [markdown]
# ## 3.1 Columns Cleanliness & Readability

# %%
# Renaming long names
rename_dict = {'Company Name': 'Company',
               ' Rocket': 'Rocket',
               'Country of Launch': 'Launch Country', 
               'Companys Country of Origin': 'Company Origin', 
               'Private or State Run': 'Ownership'}
df.rename(columns=rename_dict, inplace=True)

# Drop duplicate column
df.drop(columns=['DateTime', 'Date'], inplace=True)

# %% [markdown]
# ## 3.2 Check Missing Values

# %%
df.isna().sum()
# Out:
# Company              0
# Location             0
# Detail               0
# Status Rocket        0
# Rocket            3360
# Status Mission       0
# Launch Country       0
# Company Origin       0
# Ownership            0
# Year                 0
# Month                0
# Day                  0
# Time                 0
# dtype: int64

# %% [markdown]
# There are missing values for Rocket column

# %% [markdown]
# ### Handling Missing Values

# %%
# Adding NA column {isna:1}
df['Rocket_isna'] = np.where(df['Rocket'].isna(), 1, 0)

# Convert everything to strings and delete commas
df['Rocket'] = df['Rocket'].astype(str).str.replace(',', '').astype(float)

# %% [markdown]
# ## 3.3 Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
# Drop dupplicates
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.4 Check Data Type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4323 entries, 0 to 4323
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         4323 non-null   object
#  1   Location        4323 non-null   object
#  2   Detail          4323 non-null   object
#  3   Status Rocket   4323 non-null   object
#  4   Rocket          963 non-null    float64
#  5   Status Mission  4323 non-null   object
#  6   Launch Country  4323 non-null   object
#  7   Company Origin  4323 non-null   object
#  8   Ownership       4323 non-null   object
#  9   Year            4323 non-null   int64
#  10  Month           4323 non-null   int64
#  11  Day             4323 non-null   int64
#  12  Time            4323 non-null   object
#  13  Rocket_isna     4323 non-null   int32
# dtypes: float64(1), int32(1), int64(3), object(9)
# memory usage: 489.7+ KB

# %% [markdown]
# ## 3.5 Check Unique Values

# %%
# Count the number of unique values in each column 
df.nunique()
# Out:
# Company             55
# Location           137
# Detail            4278
# Status Rocket        2
# Rocket              56
# Status Mission       4
# Launch Country      16
# Company Origin      17
# Ownership            2
# Year                64
# Month               12
# Day                 31
# Time              1273
# Rocket_isna          2
# dtype: int64

# %% [markdown]
# ## 3.6 Check Statistics

# %%
df.describe(include='all')
# Out:
#           Company                                    Location  \
# count        4323                                        4323
# unique         55                                         137
# top     RVSN USSR  Site 31/6, Baikonur Cosmodrome, Kazakhstan
# freq         1777                                         235
# mean          NaN                                         NaN
# std           NaN                                         NaN
# min           NaN                                         NaN
# 25%           NaN                                         NaN
# 50%           NaN                                         NaN
# 75%           NaN                                         NaN
# max           NaN                                         NaN
#
#                                      Detail  Status Rocket       Rocket  \
# count                                  4323           4323   963.000000
# unique                                 4278              2          NaN
# top     Cosmos-3MRB (65MRB) | BOR-5 Shuttle  StatusRetired          NaN
# freq                                      6           3534          NaN
# mean                                    NaN            NaN   153.921007
# std                                     NaN            NaN   288.572876
# min                                     NaN            NaN     5.300000
# 25%                                     NaN            NaN    40.000000
# 50%                                     NaN            NaN    62.000000
# 75%                                     NaN            NaN   164.000000
# max                                     NaN            NaN  5000.000000
#
#        Status Mission Launch Country Company Origin Ownership         Year  \
# count            4323           4323           4323      4323  4323.000000
# unique              4             16             17         2          NaN
# top           Success         Russia         Russia         S          NaN
# freq             3878           1398           2064      2930          NaN
# mean              NaN            NaN            NaN       NaN  1987.381911
# std               NaN            NaN            NaN       NaN    18.071932
# min               NaN            NaN            NaN       NaN  1957.000000
# 25%               NaN            NaN            NaN       NaN  1972.000000
# 50%               NaN            NaN            NaN       NaN  1984.000000
# 75%               NaN            NaN            NaN       NaN  2002.000000
# max               NaN            NaN            NaN       NaN  2020.000000
#
#               Month          Day   Time  Rocket_isna
# count   4323.000000  4323.000000   4323  4323.000000
# unique          NaN          NaN   1273          NaN
# top             NaN          NaN  00:00          NaN
# freq            NaN          NaN    135          NaN
# mean       6.753181    16.441591    NaN     0.777238
# std        3.416812     8.635934    NaN     0.416148
# min        1.000000     1.000000    NaN     0.000000
# 25%        4.000000     9.000000    NaN     1.000000
# 50%        7.000000    17.000000    NaN     1.000000
# 75%       10.000000    24.000000    NaN     1.000000
# max       12.000000    31.000000    NaN     1.000000

# %% [markdown]
# ## 3.7 Check Categories

# %%
# Define numerical & categorical columns
initial_numerical_features = [feature for feature in df.columns if df[feature].dtype != 'object']
initial_categorical_features = [feature for feature in df.columns if df[feature].dtype == 'object']

print('There are possible {} numerical features: {}\n'.format(len(initial_numerical_features), initial_numerical_features))
print('There are possible {} categorical features: {}'.format(len(initial_categorical_features), initial_categorical_features))
# Out:
# There are possible 5 numerical features: ['Rocket', 'Year', 'Month', 'Day', 'Rocket_isna']
#
# There are possible 9 categorical features: ['Company', 'Location', 'Detail', 'Status Rocket', 'Status Mission', 'Launch Country', 'Company Origin', 'Ownership', 'Time']

# %% [markdown]
# ## 4. Handling Various Features

# %% [markdown]
# ### Splitting Multi-Element Categorical Feature: Location

# %%
# Calculate frequency of each category
location_freq = (df['Location'].value_counts())

# Create a dict. mapping each location name and its frequencies
location_freq_dict = location_freq.to_dict()

location_freq_dict
# Out:
# {'Site 31/6, Baikonur Cosmodrome, Kazakhstan': 235,
#  'Site 132/1, Plesetsk Cosmodrome, Russia': 216,
#  'Site 43/4, Plesetsk Cosmodrome, Russia': 202,
#  'Site 41/1, Plesetsk Cosmodrome, Russia': 198,
#  'Site 1/5, Baikonur Cosmodrome, Kazakhstan': 193,
#  'Site 132/2, Plesetsk Cosmodrome, Russia': 174,
#  'Site 133/3, Plesetsk Cosmodrome, Russia': 158,
#  'Site 43/3, Plesetsk Cosmodrome, Russia': 138,
#  'LC-39A, Kennedy Space Center, Florida, USA': 120,
#  'ELA-2, Guiana Space Centre, French Guiana, France': 118,
#  'SLC-40, Cape Canaveral AFS, Florida, USA': 111,
#  'ELA-3, Guiana Space Centre, French Guiana, France': 109,
#  'SLC-41, Cape Canaveral AFS, Florida, USA': 97,
#  'SLC-4W, Vandenberg AFB, California, USA': 93,
#  'SLC-4E, Vandenberg AFB, California, USA': 83,
#  'SLC-17A, Cape Canaveral AFS, Florida, USA': 80,
#  'SLC-36B, Cape Canaveral AFS, Florida, USA': 75,
#  'LA-Y1, Tanegashima Space Center, Japan': 73,
#  'SLC-36A, Cape Canaveral AFS, Florida, USA': 70,
#  'Site 90/20, Baikonur Cosmodrome, Kazakhstan': 69,
#  'Site 86/1, Kapustin Yar, Russia': 68,
#  'SLC-17B, Cape Canaveral AFS, Florida, USA': 67,
#  'Site 32/2, Plesetsk Cosmodrome, Russia': 64,
#  'LC-2, Xichang Satellite Launch Center, China': 60,
#  'Site 32/1, Plesetsk Cosmodrome, Russia': 58,
#  'LC-39B, Kennedy Space Center, Florida, USA': 56,
#  'Site 16/2, Plesetsk Cosmodrome, Russia': 51,
#  'SLC-2W, Vandenberg AFB, California, USA': 49,
#  'Site 45/1, Baikonur Cosmodrome, Kazakhstan': 46,
#  'Site 90/19, Baikonur Cosmodrome, Kazakhstan': 45,
#  'SLC-3W, Vandenberg AFB, California, USA': 43,
#  'SLC-3E, Vandenberg AFB, California, USA': 43,
#  'LC-3, Xichang Satellite Launch Center, China': 42,
#  'First Launch Pad, Satish Dhawan Space Centre, India': 42,
#  'SLC-37B, Cape Canaveral AFS, Florida, USA': 39,
#  'LP Odyssey, Kiritimati Launch Area, Pacific Ocean': 36,
#  'Site 9401 (SLS-2), Jiuquan Satellite Launch Center, China': 36,
#  'Mu Pad, Uchinoura Space Center, Japan': 34,
#  'Site 138 (LA-2B), Jiuquan Satellite Launch Center, China': 29,
#  'SLC-1W (75-3-4), Vandenberg AFB, California, USA': 28,
#  'ELV-1 (SLV), Guiana Space Centre, French Guiana, France': 26,
#  'Second Launch Pad, Satish Dhawan Space Centre, India': 26,
#  'Site 81/24, Baikonur Cosmodrome, Kazakhstan': 26,
#  'Mayak-2, Kapustin Yar, Russia': 25,
#  'ELS, Guiana Space Centre, French Guiana, France': 23,
#  'LC-7, Taiyuan Satellite Launch Center, China': 22,
#  'SLC-1E (75-3-5), Vandenberg AFB, California, USA': 21,
#  'LC-13, Cape Canaveral AFS, Florida, USA': 21,
#  'Stargazer, Vandenberg AFB, California, USA': 21,
#  'Site 95, Jiuquan Satellite Launch Center, China': 21,
#  'Site 81/23, Baikonur Cosmodrome, Kazakhstan': 21,
#  'LC-9, Taiyuan Satellite Launch Center, China': 21,
#  'LC-12, Cape Canaveral AFS, Florida, USA': 21,
#  'LC-14, Cape Canaveral AFS, Florida, USA': 20,
#  'Site 107/1, Kapustin Yar, Russia': 19,
#  'ELA-1, Guiana Space Centre, French Guiana, France': 15,
#  'Site 41/15, Baikonur Cosmodrome, Kazakhstan': 14,
#  'Site 901 (SLS-1), Jiuquan Satellite Launch Center, China': 13,
#  'Rocket Lab LC-1A, M?\x81hia Peninsula, New Zealand': 13,
#  'LP-0A, Wallops Flight Facility, Virginia, USA': 13,
#  'Imam Khomeini Spaceport, Semnan Space Center, Iran': 13,
#  'LC-19, Cape Canaveral AFS, Florida, USA': 12,
#  'Site 109/95, Baikonur Cosmodrome, Kazakhstan': 12,
#  'Blue Origin Launch Site, West Texas, Texas, USA': 12,
#  'SLC-6, Vandenberg AFB, California, USA': 12,
#  'Pad 1, Palmachim Airbase, Israel': 11,
#  'LC-5, Cape Canaveral AFS, Florida, USA': 11,
#  'LC-18A, Cape Canaveral AFS, Florida, USA': 11,
#  'SLC-2E (75-1-1), Vandenberg AFB, California, USA': 10,
#  'SLC-5, Vandenberg AFB, California, USA': 10,
#  'Site 370/13, Yasny Cosmodrome, Russia': 10,
#  'SLC-576E, Vandenberg AFB, California, USA': 10,
#  'LA-Y2, Tanegashima Space Center, Japan': 9,
#  'ELD, Guiana Space Centre, French Guiana, France': 8,
#  'SLV LP, Satish Dhawan Space Centre, India': 8,
#  'Site 161/35, Baikonur Cosmodrome, Kazakhstan': 8,
#  'Site 162, Baikonur Cosmodrome, Kazakhstan': 8,
#  'SM Launch Tab, San Marco Launch Platform, Kenya': 8,
#  'Site 200/39, Baikonur Cosmodrome, Kazakhstan': 8,
#  'SLC-8, Vandenberg AFB, California, USA': 7,
#  'LC-576B3, Vandenberg AFB, California, USA': 7,
#  'Taiyuan Satellite Launch Center, China': 7,
#  'LP-0B, Wallops Flight Facility, Virginia, USA': 7,
#  'Uchinoura Space Center, Japan': 7,
#  'Stargazer, Cape Canaveral AFS, Florida, USA': 6,
#  'LA-3, Wallops Flight Facility, Virginia, USA': 6,
#  'Douglas F4D Skyray, Naval Air Station Point Mugu, California, USA': 6,
#  'LA-5B, RAAF Woomera Range Complex, Australia': 6,
#  'Stargazer, Wallops Flight Facility, Virginia, USA': 5,
#  'LC-34, Cape Canaveral AFS, Florida, USA': 5,
#  'LC-101, Wenchang Satellite Launch Center, China': 5,
#  'Site 1S, Vostochny Cosmodrome, Russia': 5,
#  'Svobodny Cosmodrome, Russia': 5,
#  'NB-52B Carrier, Edwards AFB, California, USA': 5,
#  'Omelek Island, Ronald Reagan Ballistic Missile Defense Test Site, Marshall Islands, USA': 5,
#  'LC-576A2, Vandenberg AFB, California, USA': 4,
#  'SLC-20, Cape Canaveral AFS, Florida, USA': 4,
#  'Brigitte, Hammaguir, Algeria, France': 4,
#  'Vertical Launch Area, Spaceport America, New Mexico': 4,
#  'Stargazer, Ronald Reagan Ballistic Missile Defense Test Site, Marshall Islands, USA': 4,
#  'Site 175/59, Baikonur Cosmodrome, Kazakhstan': 3,
#  'Site 5020 (LA-2A), Jiuquan Satellite Launch Center, China': 3,
#  'LC-201, Wenchang Satellite Launch Center, China': 3,
#  'LC-16, Taiyuan Satellite Launch Center, China': 3,
#  'Site 110/37, Baikonur Cosmodrome, Kazakhstan': 3,
#  'VLS Pad, Alc?›ntara Launch Center, Maranh?œo, Brazil': 3,
#  'SLC-46, Cape Canaveral AFS, Florida, USA': 3,
#  'LP-1, Pacific Spaceport Complex, Alaska, USA': 3,
#  'LC-1, Naro Space Center, South Korea': 3,
#  'SLC-N, Tanegashima Space Center, Japan': 3,
#  'Pad 1, Sohae Satellite Launching Station, North Korea': 3,
#  'Site 110/38, Baikonur Cosmodrome, Kazakhstan': 2,
#  'Site 191/66, Baikonur Cosmodrome, Kazakhstan': 2,
#  'Site 45/2, Baikonur Cosmodrome, Kazakhstan': 2,
#  'Site 35/1, Plesetsk Cosmodrome, Russia': 2,
#  'Pad 1, Tonghae Satellite Launching Ground, North Korea': 2,
#  'Stargazer, Base Aerea de Gando, Gran Canaria': 2,
#  'Site 158, Plesetsk Cosmodrome, Russia': 2,
#  'Site 175/58, Baikonur Cosmodrome, Kazakhstan': 2,
#  'LC-26A, Cape Canaveral AFS, Florida, USA': 2,
#  'LC-18B, Cape Canaveral AFS, Florida, USA': 1,
#  'LC-11, Cape Canaveral AFS, Florida, USA': 1,
#  'Xichang Satellite Launch Center, China': 1,
#  'Santa Rita 2, San Marco Launch Platform, Kenya': 1,
#  'LC-576A1, Vandenberg AFB, California, USA': 1,
#  'Site 250, Baikonur Cosmodrome, Kazakhstan': 1,
#  'Pad A, Boca Chica, Texas, USA': 1,
#  'Site 131/29, Baikonur Cosmodrome, Kazakhstan': 1,
#  'NB-52B Carrier, Cape Canaveral AFS, Florida, USA': 1,
#  'K-407 Submarine, Barents Sea Launch Area, Barents Sea': 1,
#  'Cosmic Girl, Mojave Air and Space Port, California, USA': 1,
#  'K-84 Submarine, Barents Sea Launch Area, Barents Sea': 1,
#  'Jiuquan Satellite Launch Center, China': 1,
#  'LP-41, Kauai, Pacific Missile Range Facility': 1,
#  'Tai Rui Barge, Yellow Sea': 1,
#  'Launch Plateform, Shahrud Missile Test Site': 1,
#  'K-496 Submarine, Barents Sea Launch Area, Barents Sea': 1}

# %% [markdown]
# There may be value in extracting the information from this column into additional features.
# It looks like the information is broken down into the follow format:
#
# U.S has 4 commas separator highlighting - Launch Pad, Facility, State, Country
# Other coutries has 3 commas separator - Launch Pad, Facility, Country
#
# Launch Pad & Facility may be of use because we already have another categorical feature detailing the Launch Counntry.

# %%
# Split location information into separate columns 
split_locations = df['Location'].str.split(', ', n=4, expand=True)

# Extract 'Launch Pad' and 'Facility' components
df.loc[:, 'Launch Pad'] = split_locations[0]
df.loc[:, 'Facility'] = split_locations[1]

# Drop 'Location'
df.drop(columns=['Location'], inplace=True)

df
# Out:
# C:\Users\Lepaulhz\AppData\Local\Temp\ipykernel_44172\3509105634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Launch Pad'] = split_locations[0]
# C:\Users\Lepaulhz\AppData\Local\Temp\ipykernel_44172\3509105634.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Facility'] = split_locations[1]
# C:\Users\Lepaulhz\AppData\Local\Temp\ipykernel_44172\3509105634.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Location'], inplace=True)
#         Company                                        Detail  Status Rocket  \
# 0        SpaceX  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky   StatusActive
# 1         CASIC           Long March 2D | Gaofen-9 04 & Q-SAT   StatusActive
# 2        SpaceX            Starship Prototype | 150 Meter Hop   StatusActive
# 3     Roscosmos  Proton-M/Briz-M | Ekspress-80 & Ekspress-103   StatusActive
# 4           ULA                    Atlas V 541 | Perseverance   StatusActive
# ...         ...                                           ...            ...
# 4319    US Navy                     Vanguard | Vanguard TV3BU  StatusRetired
# 4320       AMBA                           Juno I | Explorer 1  StatusRetired
# 4321    US Navy                       Vanguard | Vanguard TV3  StatusRetired
# 4322  RVSN USSR                    Sputnik 8K71PS | Sputnik-2  StatusRetired
# 4323  RVSN USSR                    Sputnik 8K71PS | Sputnik-1  StatusRetired
#
#       Rocket Status Mission Launch Country Company Origin Ownership  Year  \
# 0      50.00        Success            USA            USA         P  2020
# 1      29.75        Success          China          China         S  2020
# 2        NaN        Success            USA            USA         P  2020
# 3      65.00        Success     Kazakhstan         Russia         S  2020
# 4     145.00        Success            USA            USA         P  2020
# ...      ...            ...            ...            ...       ...   ...
# 4319     NaN        Failure            USA            USA         S  1958
# 4320     NaN        Success            USA            USA         S  1958
# 4321     NaN        Failure            USA            USA         S  1957
# 4322     NaN        Success     Kazakhstan         Russia         S  1957
# 4323     NaN        Success     Kazakhstan         Russia         S  1957
#
#       Month  Day   Time  Rocket_isna         Launch Pad  \
# 0         8    7  05:12            0             LC-39A
# 1         8    6  04:01            0  Site 9401 (SLS-2)
# 2         8    4  23:57            1              Pad A
# 3         7   30  21:25            0        Site 200/39
# 4         7   30  11:50            0             SLC-41
# ...     ...  ...    ...          ...                ...
# 4319      2    5  07:33            1             LC-18A
# 4320      2    1  03:48            1             LC-26A
# 4321     12    6  16:44            1             LC-18A
# 4322     11    3  02:30            1           Site 1/5
# 4323     10    4  19:28            1           Site 1/5
#
#                              Facility
# 0                Kennedy Space Center
# 1     Jiuquan Satellite Launch Center
# 2                          Boca Chica
# 3                 Baikonur Cosmodrome
# 4                  Cape Canaveral AFS
# ...                               ...
# 4319               Cape Canaveral AFS
# 4320               Cape Canaveral AFS
# 4321               Cape Canaveral AFS
# 4322              Baikonur Cosmodrome
# 4323              Baikonur Cosmodrome
#
# [4323 rows x 15 columns]

# %% [markdown]
# ### Splitting Multi-Element Categorical Feature: Detail

# %%
df['Detail'].head(20)
# Out:
# 0          Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1                   Long March 2D | Gaofen-9 04 & Q-SAT
# 2                    Starship Prototype | 150 Meter Hop
# 3          Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4                            Atlas V 541 | Perseverance
# 5     Long March 4B | Ziyuan-3 03, Apocalypse-10 & N...
# 6                           Soyuz 2.1a | Progress MS-15
# 7                              Long March 5 | Tianwen-1
# 8                          Falcon 9 Block 5 | ANASIS-II
# 9                         H-IIA 202 | Hope Mars Mission
# 10                               Minotaur IV | NROL-129
# 11           Kuaizhou 11 | Jilin-1 02E, CentiSpace-1 S2
# 12                          Long March 3B/E | Apstar-6D
# 13                                   Shavit-2 | Ofek-16
# 14                          Long March 2D | Shiyan-6 02
# 15          Electron/Curie | Pics Or It Didn??¦t Happen
# 16                 Long March 4B | Gaofen Duomo & BY-02
# 17                      Falcon 9 Block 5 | GPS III SV03
# 18                        Long March 3B/E | Beidou-3 G3
# 19    Long March 2D | Gaofen-9 03, Pixing III A & HE...
# Name: Detail, dtype: object

# %% [markdown]
# Detail column has high number of unique value so there is no point to pursue frequency mapping.
# From observation, it looks like the information is broken down as follow:
#
# Space Vehicle | Mission
#
# There is more interest to capture the information for Space Vehicle because missions will be unique and different each launch.

# %%
# Split Detail information into separate columns 
split_details = df['Detail'].str.split(' | ', n=2, expand=True)

# Extract 'Space Vehicle' components
df.loc[:, 'Space Vehicle'] = split_details[0]

# Drop 'Detail'
df.drop(columns=['Detail'], inplace=True)

df
# Out:
# C:\Users\Lepaulhz\AppData\Local\Temp\ipykernel_44172\2119277179.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'Space Vehicle'] = split_details[0]
# C:\Users\Lepaulhz\AppData\Local\Temp\ipykernel_44172\2119277179.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Detail'], inplace=True)
#         Company  Status Rocket  Rocket Status Mission Launch Country  \
# 0        SpaceX   StatusActive   50.00        Success            USA
# 1         CASIC   StatusActive   29.75        Success          China
# 2        SpaceX   StatusActive     NaN        Success            USA
# 3     Roscosmos   StatusActive   65.00        Success     Kazakhstan
# 4           ULA   StatusActive  145.00        Success            USA
# ...         ...            ...     ...            ...            ...
# 4319    US Navy  StatusRetired     NaN        Failure            USA
# 4320       AMBA  StatusRetired     NaN        Success            USA
# 4321    US Navy  StatusRetired     NaN        Failure            USA
# 4322  RVSN USSR  StatusRetired     NaN        Success     Kazakhstan
# 4323  RVSN USSR  StatusRetired     NaN        Success     Kazakhstan
#
#      Company Origin Ownership  Year  Month  Day   Time  Rocket_isna  \
# 0               USA         P  2020      8    7  05:12            0
# 1             China         S  2020      8    6  04:01            0
# 2               USA         P  2020      8    4  23:57            1
# 3            Russia         S  2020      7   30  21:25            0
# 4               USA         P  2020      7   30  11:50            0
# ...             ...       ...   ...    ...  ...    ...          ...
# 4319            USA         S  1958      2    5  07:33            1
# 4320            USA         S  1958      2    1  03:48            1
# 4321            USA         S  1957     12    6  16:44            1
# 4322         Russia         S  1957     11    3  02:30            1
# 4323         Russia         S  1957     10    4  19:28            1
#
#              Launch Pad                         Facility    Space Vehicle
# 0                LC-39A             Kennedy Space Center           Falcon
# 1     Site 9401 (SLS-2)  Jiuquan Satellite Launch Center             Long
# 2                 Pad A                       Boca Chica         Starship
# 3           Site 200/39              Baikonur Cosmodrome  Proton-M/Briz-M
# 4                SLC-41               Cape Canaveral AFS            Atlas
# ...                 ...                              ...              ...
# 4319             LC-18A               Cape Canaveral AFS         Vanguard
# 4320             LC-26A               Cape Canaveral AFS             Juno
# 4321             LC-18A               Cape Canaveral AFS         Vanguard
# 4322           Site 1/5              Baikonur Cosmodrome          Sputnik
# 4323           Site 1/5              Baikonur Cosmodrome          Sputnik
#
# [4323 rows x 15 columns]

# %%
df.describe(include='all')
# Out:
#           Company  Status Rocket       Rocket Status Mission Launch Country  \
# count        4323           4323   963.000000           4323           4323
# unique         55              2          NaN              4             16
# top     RVSN USSR  StatusRetired          NaN        Success         Russia
# freq         1777           3534          NaN           3878           1398
# mean          NaN            NaN   153.921007            NaN            NaN
# std           NaN            NaN   288.572876            NaN            NaN
# min           NaN            NaN     5.300000            NaN            NaN
# 25%           NaN            NaN    40.000000            NaN            NaN
# 50%           NaN            NaN    62.000000            NaN            NaN
# 75%           NaN            NaN   164.000000            NaN            NaN
# max           NaN            NaN  5000.000000            NaN            NaN
#
#        Company Origin Ownership         Year        Month          Day   Time  \
# count            4323      4323  4323.000000  4323.000000  4323.000000   4323
# unique             17         2          NaN          NaN          NaN   1273
# top            Russia         S          NaN          NaN          NaN  00:00
# freq             2064      2930          NaN          NaN          NaN    135
# mean              NaN       NaN  1987.381911     6.753181    16.441591    NaN
# std               NaN       NaN    18.071932     3.416812     8.635934    NaN
# min               NaN       NaN  1957.000000     1.000000     1.000000    NaN
# 25%               NaN       NaN  1972.000000     4.000000     9.000000    NaN
# 50%               NaN       NaN  1984.000000     7.000000    17.000000    NaN
# 75%               NaN       NaN  2002.000000    10.000000    24.000000    NaN
# max               NaN       NaN  2020.000000    12.000000    31.000000    NaN
#
#         Rocket_isna Launch Pad             Facility Space Vehicle
# count   4323.000000       4323                 4323          4323
# unique          NaN        130                   44           128
# top             NaN  Site 31/6  Plesetsk Cosmodrome     Cosmos-3M
# freq            NaN        235                 1263           446
# mean       0.777238        NaN                  NaN           NaN
# std        0.416148        NaN                  NaN           NaN
# min        0.000000        NaN                  NaN           NaN
# 25%        1.000000        NaN                  NaN           NaN
# 50%        1.000000        NaN                  NaN           NaN
# 75%        1.000000        NaN                  NaN           NaN
# max        1.000000        NaN                  NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4323 entries, 0 to 4323
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company         4323 non-null   object
#  1   Status Rocket   4323 non-null   object
#  2   Rocket          963 non-null    float64
#  3   Status Mission  4323 non-null   object
#  4   Launch Country  4323 non-null   object
#  5   Company Origin  4323 non-null   object
#  6   Ownership       4323 non-null   object
#  7   Year            4323 non-null   int64
#  8   Month           4323 non-null   int64
#  9   Day             4323 non-null   int64
#  10  Time            4323 non-null   object
#  11  Rocket_isna     4323 non-null   int32
#  12  Launch Pad      4323 non-null   object
#  13  Facility        4323 non-null   object
#  14  Space Vehicle   4323 non-null   object
# dtypes: float64(1), int32(1), int64(3), object(10)
# memory usage: 523.5+ KB

# %% [markdown]
# ### Handling High Cardinality Categorical Features (4):
# ### Company, Launch Pad, Facility, Space Vehicle

# %%
high_cardinality_features = ['Company', 'Launch Pad', 'Facility', 'Space Vehicle']

# Step 1: Store the frequency dictionary in the high_freq_dict dictionary
high_freq_dict = {}
for feature in high_cardinality_features:
    high_freq_dict[feature] = df[feature].value_counts().to_dict()

for feature, high_freq in high_freq_dict.items():
    print(f"Frequency dictionary for {feature}:")
    print(high_freq, '\n')
    
# Step 2: Define function to use in FunctionTransformer
#         map features to frequencies
def map_features_to_freq(i, freq_dict):
    return np.vectorize(lambda x: freq_dict.get(x, 0))(i)

# Step 3: Creating pipeline
high_cardinality_pipeline = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
                                            ('frequency_mapper', FunctionTransformer(map_features_to_freq, kw_args={'freq_dict': high_freq_dict}))])
# Out:
# Frequency dictionary for Company:
# {'RVSN USSR': 1777, 'Arianespace': 279, 'CASIC': 255, 'General Dynamics': 251, 'NASA': 203, 'VKS RF': 201, 'US Air Force': 161, 'ULA': 140, 'Boeing': 136, 'Martin Marietta': 114, 'SpaceX': 100, 'MHI': 84, 'Northrop': 83, 'Lockheed': 79, 'ISRO': 76, 'Roscosmos': 55, 'ILS': 46, 'Sea Launch': 36, 'ISAS': 30, 'Kosmotras': 22, 'US Navy': 17, 'Rocket Lab': 13, 'Eurockot': 13, 'ESA': 13, 'ISA': 13, 'Blue Origin': 12, 'IAI': 11, 'ExPace': 10, 'ASI': 9, 'CNES': 8, 'AMBA': 8, 'MITT': 7, 'Land Launch': 7, 'JAXA': 7, 'UT': 5, 'KCST': 5, 'Exos': 4, 'CECLES': 4, "Arme de l'Air": 4, 'SRC': 3, 'AEB': 3, 'KARI': 3, 'RAE': 2, 'OKB-586': 2, 'Yuzhmash': 2, 'Landspace': 1, 'Starsem': 1, 'Douglas': 1, 'EER': 1, 'Virgin Orbit': 1, 'IRGC': 1, 'i-Space': 1, 'OneSpace': 1, 'Sandia': 1, 'Khrunichev': 1}
#
# Frequency dictionary for Launch Pad:
# {'Site 31/6': 235, 'Site 132/1': 216, 'Site 43/4': 202, 'Site 41/1': 198, 'Site 1/5': 193, 'Site 132/2': 174, 'Site 133/3': 158, 'Site 43/3': 138, 'LC-39A': 120, 'ELA-2': 118, 'SLC-40': 111, 'ELA-3': 109, 'SLC-41': 97, 'SLC-4W': 93, 'SLC-4E': 83, 'SLC-17A': 80, 'SLC-36B': 75, 'LA-Y1': 73, 'SLC-36A': 70, 'Site 90/20': 69, 'Site 86/1': 68, 'SLC-17B': 67, 'Site 32/2': 64, 'LC-2': 60, 'Site 32/1': 58, 'LC-39B': 56, 'Site 16/2': 51, 'SLC-2W': 49, 'Site 45/1': 46, 'Site 90/19': 45, 'SLC-3W': 43, 'SLC-3E': 43, 'LC-3': 42, 'First Launch Pad': 42, 'SLC-37B': 39, 'Stargazer': 38, 'LP Odyssey': 36, 'Site 9401 (SLS-2)': 36, 'Mu Pad': 34, 'Site 138 (LA-2B)': 29, 'SLC-1W (75-3-4)': 28, 'Second Launch Pad': 26, 'Site 81/24': 26, 'ELV-1 (SLV)': 26, 'Mayak-2': 25, 'ELS': 23, 'LC-7': 22, 'Site 81/23': 21, 'SLC-1E (75-3-5)': 21, 'LC-13': 21, 'LC-12': 21, 'LC-9': 21, 'Site 95': 21, 'LC-14': 20, 'Site 107/1': 19, 'Pad 1': 16, 'ELA-1': 15, 'Site 41/15': 14, 'Rocket Lab LC-1A': 13, 'Site 901 (SLS-1)': 13, 'Imam Khomeini Spaceport': 13, 'LP-0A': 13, 'LC-19': 12, 'Site 109/95': 12, 'SLC-6': 12, 'Blue Origin Launch Site': 12, 'LC-5': 11, 'LC-18A': 11, 'SLC-2E (75-1-1)': 10, 'SLC-576E': 10, 'SLC-5': 10, 'Site 370/13': 10, 'LA-Y2': 9, 'SM Launch Tab': 8, 'Site 200/39': 8, 'SLV LP': 8, 'ELD': 8, 'Site 162': 8, 'Site 161/35': 8, 'LC-576B3': 7, 'Uchinoura Space Center': 7, 'Taiyuan Satellite Launch Center': 7, 'LP-0B': 7, 'SLC-8': 7, 'Douglas F4D Skyray': 6, 'LA-3': 6, 'LA-5B': 6, 'NB-52B Carrier': 6, 'Site 1S': 5, 'LC-34': 5, 'LC-101': 5, 'Omelek Island': 5, 'Svobodny Cosmodrome': 5, 'Brigitte': 4, 'LC-576A2': 4, 'Vertical Launch Area': 4, 'SLC-20': 4, 'SLC-46': 3, 'VLS Pad': 3, 'LC-201': 3, 'Site 110/37': 3, 'Site 175/59': 3, 'LC-1': 3, 'LP-1': 3, 'LC-16': 3, 'SLC-N': 3, 'Site 5020 (LA-2A)': 3, 'Site 110/38': 2, 'LC-26A': 2, 'Site 191/66': 2, 'Site 45/2': 2, 'Site 175/58': 2, 'Site 158': 2, 'Site 35/1': 2, 'K-84 Submarine': 1, 'Launch Plateform': 1, 'LC-11': 1, 'Tai Rui Barge': 1, 'LP-41': 1, 'LC-18B': 1, 'Jiuquan Satellite Launch Center': 1, 'Cosmic Girl': 1, 'K-496 Submarine': 1, 'Santa Rita 2': 1, 'K-407 Submarine': 1, 'Site 131/29': 1, 'Pad A': 1, 'Site 250': 1, 'LC-576A1': 1, 'Xichang Satellite Launch Center': 1}
#
# Frequency dictionary for Facility:
# {'Plesetsk Cosmodrome': 1263, 'Baikonur Cosmodrome': 701, 'Cape Canaveral AFS': 658, 'Vandenberg AFB': 442, 'Guiana Space Centre': 299, 'Kennedy Space Center': 176, 'Kapustin Yar': 112, 'Xichang Satellite Launch Center': 102, 'Jiuquan Satellite Launch Center': 102, 'Tanegashima Space Center': 85, 'Satish Dhawan Space Centre': 76, 'Taiyuan Satellite Launch Center': 46, 'Kiritimati Launch Area': 36, 'Uchinoura Space Center': 34, 'Wallops Flight Facility': 31, 'M?\x81hia Peninsula': 13, 'Semnan Space Center': 13, 'West Texas': 12, 'Palmachim Airbase': 11, 'Yasny Cosmodrome': 10, 'China': 9, 'San Marco Launch Platform': 9, 'Ronald Reagan Ballistic Missile Defense Test Site': 9, 'Wenchang Satellite Launch Center': 8, 'Japan': 7, 'Naval Air Station Point Mugu': 6, 'RAAF Woomera Range Complex': 6, 'Vostochny Cosmodrome': 5, 'Edwards AFB': 5, 'Russia': 5, 'Hammaguir': 4, 'Spaceport America': 4, 'Sohae Satellite Launching Station': 3, 'Alc?›ntara Launch Center': 3, 'Barents Sea Launch Area': 3, 'Pacific Spaceport Complex': 3, 'Naro Space Center': 3, 'Tonghae Satellite Launching Ground': 2, 'Base Aerea de Gando': 2, 'Shahrud Missile Test Site': 1, 'Boca Chica': 1, 'Mojave Air and Space Port': 1, 'Kauai': 1, 'Yellow Sea': 1}
#
# Frequency dictionary for Space Vehicle:
# {'Cosmos-3M': 446, 'Voskhod': 299, 'Molniya-M': 280, 'Soyuz': 254, 'Ariane': 252, 'Long': 238, 'Titan': 213, 'Delta': 203, 'Atlas': 166, 'Cosmos-2I': 164, 'Space': 135, 'Tsyklon-3': 122, 'Tsyklon-2': 106, 'Falcon': 99, 'Vostok-2M': 93, 'Thor': 62, 'Atlas-SLV3': 49, 'Atlas-LV3': 47, 'Zenit-3': 46, 'Atlas-E/F': 46, 'Vostok-2': 45, 'Pegasus': 42, 'H-IIA': 42, 'Molniya': 40, 'Proton': 39, 'Zenit-2': 38, 'Rokot/Briz': 34, 'Atlas-SLV3D': 32, 'Saturn': 29, 'Minotaur': 27, 'Vostok': 26, 'Scout': 25, 'PSLV-XL': 22, 'Dnepr': 22, 'Atlas-D': 20, 'Mu-III': 19, 'Cosmos-3MRB': 19, 'Tsyklon': 18, 'GSLV': 17, 'Atlas-SLV3C': 17, 'Thor-DM18': 16, 'Vega': 15, 'PSLV-CA': 14, 'Proton-M/Briz-M': 13, 'Kuaizhou': 12, 'H-I': 12, 'Electron/Curie': 12, 'Atlas-SLV3A': 12, 'Antares': 12, 'PSLV-G': 12, 'Diamant': 12, 'New': 12, 'Atlas-LV3C': 12, 'Feng': 11, 'Thor-DM21': 11, 'Vanguard': 11, 'H-IIB': 9, 'N-II': 8, 'Tsyklon-2A': 8, 'Cosmos-1': 8, 'N-I': 7, 'Atlas-G': 7, 'Juno': 7, 'Athena': 7, 'Mu-V': 7, 'NOTS-EV-1': 6, 'H-II': 6, 'Mercury-Redstone': 6, 'Safir-1B+': 6, 'Cosmos-3': 6, 'Start-1': 6, 'Atlas-H': 5, 'Shavit-2': 5, 'Lambda-IV': 5, 'N1-L3': 4, 'SARGE': 4, 'Epsilon': 4, 'Europa': 4, 'Mu-IV': 4, 'SLV-3': 4, 'Sputnik': 4, 'ASLV': 4, 'Commercial': 4, 'Shavit': 4, 'VLS-1': 3, 'Strela': 3, 'Titan-III(33)B': 3, 'Kaituozhe': 3, 'Simorgh': 3, 'Unha-3': 3, 'Naro-1': 3, 'Proton-M/DM-3': 3, 'Thor-DM': 3, 'Angara': 2, 'Safir-1': 2, 'Shavit-1': 2, 'PSLV-QL': 2, 'Vostok-2A': 2, 'SS-520': 2, "Shtil'": 2, 'Black': 2, 'Poliot': 2, 'Pegasus/HAPS': 2, 'Conestoga-1620': 1, 'Blue': 1, 'Qased': 1, 'LauncherOne': 1, 'SM-65B': 1, 'Starship': 1, 'Taepodong-1': 1, 'Atlas-SLV3B': 1, 'Unha-2': 1, 'Start': 1, 'Jielong-1': 1, 'Hyperbola-1': 1, 'OS-M1': 1, 'Redstone': 1, 'PSLV-DL': 1, 'Ares': 1, 'ZhuQue-1': 1, 'H-IIS': 1, 'Electron': 1, 'Super': 1, 'Safir-1B': 1, 'Safir-1A': 1, 'Energiya/Buran': 1, 'Energiya/Polyus': 1, 'Volna': 1}

# %%
# EXAMPLE COMPANY)
example_company = df['Company']

result_company = map_features_to_freq(example_company, high_freq_dict['Company'])
print("\nResult for Company:")
print(result_company)
print(type(result_company))
# Out:
# Result for Company:
# [ 100  255  100 ...   17 1777 1777]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Handling Low Cardinality Categorical Features (2):
# ### Launch Country, Company Origin

# %%
low_cardinality_features = ['Launch Country','Company Origin']

# Step 1: Store the top 10 most frequent unique count 
top10_low_freq_dict = {}
for feature in low_cardinality_features:
    top10_low_freq_dict[feature] = df[feature].value_counts().head(10).to_dict()
    
for feature, low_freq in top10_low_freq_dict.items():
    print(f"Frequency dictionary for {feature}:")
    print(low_freq, '\n')

# Step 2: Define function to use in FunctionTransformer
#         to select top 10 most frequent unique count
def select_top10_freq(i, top10_dict):
    return np.vectorize(lambda x: top10_dict.get(x, 0))(i)

# Step 3: Creating pipeline
low_cardinality_pipeline = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
                                           ('top10_selector', FunctionTransformer(select_top10_freq, kw_args={'top10_dict': top10_low_freq_dict})),
                                           ('onehot', OneHotEncoder(drop='first', handle_unknown='error'))])
# Out:
# Frequency dictionary for Launch Country:
# {'Russia': 1398, 'USA': 1351, 'Kazakhstan': 701, 'France': 303, 'China': 268, 'Japan': 126, 'India': 76, 'Sea Launch': 36, 'Iran': 14, 'New Zealand': 13}
#
# Frequency dictionary for Company Origin:
# {'Russia': 2064, 'USA': 1374, 'Multi': 339, 'China': 268, 'Japan': 126, 'India': 76, 'Isreal': 24, 'Germany': 13, 'Italy': 9, 'France': 8}

# %%
# EXAMPLE LAUNCH COUNTRY) 

example_launch_country = df['Launch Country']

result_launch_country = select_top10_freq(example_launch_country, top10_low_freq_dict['Launch Country'])
print("Result for Launch Country:")
print(result_launch_country)
print(type(result_launch_country))
# Out:
# Result for Launch Country:
# [1351  268 1351 ... 1351  701  701]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Handling Categorical Time Feature (1):
# ### Time

# %% [raw]
# def map_hour_to_quarter(hour_str):
#     hour = int(hour_str.replace(':', ''))
#     if hour < 600:
#         return 1
#     elif hour < 1200:
#         return 2
#     elif hour < 1800:
#         return 3
#     else:
#         return 4
#
# time_cardinality_pipeline = Pipeline(steps=[('map_hour_to_quarter', FunctionTransformer(map_hour_to_quarter))])

# %% [raw]
# # EXAMPLE TIME)
#
# # Sample input data for testing
# sample_data = df['Time']
#
# # Apply the time_pipeline to the sample data
# transformed_data = time_cardinality_pipeline.fit_transform(sample_data)
#
# # Print the transformed data
# print(transformed_data)

# %% [markdown]
# ### Handling Binary Feature (2):
# ### Rocket Status, Ownership

# %%
binary_features = ['Status Rocket', 'Ownership', 'Rocket_isna']

# Step 1: Store the binary dictionary 
binary_dict = {}
for feature in binary_features:
    if feature == 'Status Rocket':
        binary_dict[feature] = {'StatusActive': 1, 'StatusRetired': 0}
    elif feature == 'Ownership':
        binary_dict[feature] = {'S': 1, 'P': 0}
    elif feature == 'Rocket_isna':
        binary_dict[feature] = {1: 1, 0: 0}


# Step 2: Define function to use in FunctionTransformer
#         map features to binary
def map_binary(i, bin_dict):
    return np.vectorize(lambda x: bin_dict.get(x, 0))(i)

# Step 3: Creating pipeline
binary_cardinality_pipeline = Pipeline(steps=[('binary_encode', FunctionTransformer(map_binary, kw_args={'bin_dict': binary_dict}))])

# %%
# EXAMPLE STATUS ROCKET) 
example_status_rocket = df['Status Rocket']

result_status_rocket = map_binary(example_status_rocket, binary_dict['Status Rocket'])
print("Result for Status Rocket:")
print(result_status_rocket)
print(type(result_status_rocket))
# Out:
# Result for Status Rocket:
# [1 1 1 ... 0 0 0]
# <class 'numpy.ndarray'>

# %%
categorical_features = low_cardinality_features + high_cardinality_features + binary_features
categorical_features
# Out:
# ['Launch Country',
#  'Company Origin',
#  'Company',
#  'Launch Pad',
#  'Facility',
#  'Space Vehicle',
#  'Status Rocket',
#  'Ownership',
#  'Rocket_isna']

# %% [markdown]
# ### Handling Categorical Target Feature (1):
# ### Status Mission

# %%
df.loc[:, 'Status Mission'] = (df['Status Mission'] == 'Success')

# %% [markdown]
# ### Handling Numerical Features (4):
# ### Rocket, Year, Month, Day

# %%
numerical_features =  ['Rocket', 'Year', 'Month', 'Day']

imp_strat = 'constant'
numerical_pipeline =  Pipeline([('imputer', SimpleImputer(strategy=imp_strat, fill_value=0)),  
                                ('scaler', StandardScaler())])

# %%
# EXAMPLE ROCKET) 

example_rocket = df['Rocket']
print(type(example_rocket[1]))
# Out:
# <class 'numpy.float64'>

# %% [markdown]
# ## 5. Preprocessor

# %%
# W/O Time
# ('time', time_cardinality_pipeline, ['Time'])

categorical_preprocessor = ColumnTransformer(
    transformers=[('high_cardinality', high_cardinality_pipeline, high_cardinality_features),
                  ('low_cardinality', low_cardinality_pipeline, low_cardinality_features),
                  ('binary_cardinality', binary_cardinality_pipeline, binary_features)])

numerical_preprocessor = ColumnTransformer(
    transformers=[('numerical_scaling', numerical_pipeline, numerical_features)])

preprocessor = ColumnTransformer(
    transformers=[('numerical', numerical_preprocessor, numerical_features),
                  ('categorical', categorical_preprocessor, categorical_features)])

# %%
X = df[categorical_features+numerical_features]
y = df['Status Mission'].astype(int)

# %%
# Splitting the dataset into Test|Train : 30|70 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=21)

# %%
final_pipe = make_pipeline(preprocessor, LogisticRegression())
set_config(display='diagram')
display(final_pipe)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   ColumnTransformer(transformers=[('numerical_scaling',
#                                                                                    Pipeline(steps=[('imputer',
#                                                                                                     SimpleImputer(fill_value=0,
#                                                                                                                   strategy='constant')),
#                                                                                                    ('scaler',
#                                                                                                     StandardScaler())]),
#                                                                                    ['Rocket',
#                                                                                     'Year',
#                                                                                     'Month',
#                                                                                     'Day'])]),
#                                                   ['Rocket', 'Year', 'Month',
#                                                    'Day']),
#                                                  ('categorical',
#                                                   ColumnTransformer(transfor...
#                                                                                                     FunctionTransformer(func=<function map_binary at 0x000002858A046D40>,
#                                                                                                                         kw_args={'bin_dict': {'Ownership': {'P': 0,
#                                                                                                                                                             'S': 1},
#                                                                                                                                               'Rocket_isna': {0: 0,
#                                                                                                                                                               1: 1},
#                                                                                                                                               'Status Rocket': {'StatusActive': 1,
#                                                                                                                                                                 'StatusRetired': 0}}}))]),
#                                                                                    ['Status '
#                                                                                     'Rocket',
#                                                                                     'Ownership',
#                                                                                     'Rocket_isna'])]),
#                                                   ['Launch Country',
#                                                    'Company Origin', 'Company',
#                                                    'Launch Pad', 'Facility',
#                                                    'Space Vehicle',
#                                                    'Status Rocket', 'Ownership',
#                                                    'Rocket_isna'])])),
#                 ('logisticregression', LogisticRegression())])

# %%
# Fit and transform the training data using the final pipeline
X_train_processed = final_pipe.named_steps['columntransformer'].fit_transform(X_train, y_train)

# %%
# Transform the test data using the preprocessor
X_test_processed = final_pipe.named_steps['columntransformer'].transform(X_test)

# %% [markdown]
# ## 6. Model

# %%
models = {'Logistic Regression': LogisticRegression()}

for name, model in models.items():
    model.fit(X_train_processed, y_train)
    y_train_prediction = model.predict(X_train_processed)
    y_test_prediction = model.predict(X_test_processed)
    
    train_accuracy = model.score(X_train_processed, y_train)
    test_accuracy = model.score(X_test_processed, y_test)
    
    print(f'{name} Trained Accuracy: {train_accuracy*100: .2f}%')
    print(f'{name} Tested Accuracy: {test_accuracy*100: .2f}%')
    
    error_train = y_train_prediction - y_train
    error_test = y_test_prediction - y_test
    
    # Calculate the number of occurrences of 0 error
    zero_error_train_count = (error_train == 0).sum()
    zero_error_test_count = (error_test == 0).sum()

    zero_error_train_percent = (zero_error_train_count/len(error_train))*100
    zero_error_test_percent = (zero_error_test_count/len(error_test))*100
    print('\nManual no score method')
    print(f'{name} Trained Score: {zero_error_train_percent: .2f}%')
    print(f'{name} Tested Score: {zero_error_test_percent: .2f}%')
    

    con_matrix = confusion_matrix(y_test, y_test_prediction)
    true_negative = con_matrix[0,0]
    false_positive = con_matrix[0,1]
    false_negative = con_matrix[1,0]
    true_positive = con_matrix[1,1]
    print('')
    print('True Negative:', true_negative)
    print('False Positive:', false_positive)
    print('False Negative:', false_negative)
    print('True Positive:', true_positive)
    
    
    report = classification_report(y_test, y_test_prediction)
    print('')
    print(report)
    # Split the report into lines and extract the line containing metrics for the desired class
    lines = report.split('\n')
    target_class_line = lines[3]  # Assuming the desired class is at index 3

    # Split the line by whitespace and extract precision, recall, and F1-score
    precision, recall, f1_score, support = target_class_line.split()[1:]

    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1_score)
# Out:
# Logistic Regression Trained Accuracy:  89.76%
# Logistic Regression Tested Accuracy:  89.59%
#
# Manual no score method
# Logistic Regression Trained Score:  89.76%
# Logistic Regression Tested Score:  89.59%
#
# True Negative: 0
# False Positive: 135
# False Negative: 0
# True Positive: 1162
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       135
#            1       0.90      1.00      0.95      1162
#
#     accuracy                           0.90      1297
#    macro avg       0.45      0.50      0.47      1297
# weighted avg       0.80      0.90      0.85      1297
#
# Precision: 0.90
# Recall: 1.00
# F1-score: 0.95
# C:\Users\Lepaulhz\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lepaulhz\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lepaulhz\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
X_train.shape
# Out:
# (3026, 13)

# %%
X_train_processed.shape
# Out:
# (3026, 11)

# %%
df_train_processed = pd.DataFrame(X_train_processed, columns=numerical_features + categorical_features)
df_train_processed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df_train_processed = pd.DataFrame(X_train_processed, columns=numerical_features + categorical_features)
#       2 df_train_processed
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:758, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     747         mgr = dict_to_mgr(
#     748             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     749             # attribute "name"
#    (...)
#     755             copy=_copy,
#     756         )
#     757     else:
# --> 758         mgr = ndarray_to_mgr(
#     759             data,
#     760             index,
#     761             columns,
#     762             dtype=dtype,
#     763             copy=copy,
#     764             typ=manager,
#     765         )
#     767 # For data is list-like, or Iterable (will consume into list)
#     768 elif is_list_like(data):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:337, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     332 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     333 index, columns = _get_axes(
#     334     values.shape[0], values.shape[1], index=index, columns=columns
#     335 )
# --> 337 _check_values_indices_shape_match(values, index, columns)
#     339 if typ == "array":
#     340     if issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:408, in _check_values_indices_shape_match(values, index, columns)
#     406 passed = values.shape
#     407 implied = (len(index), len(columns))
# --> 408 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (3026, 11), indices imply (3026, 13)

# %% [raw]
# csv_file = 'metric.csv'
#
# # Create a dictionary with the variables
# row = {
#     'Timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
#     'Impute Method': imp_strat,
#     'Precision': precision,
#     'Recall': recall,
#     'F1-score': f1_score,
#     'True Positive': true_positive,
#     'False Positive': false_positive,
#     'False Negative': false_negative,
#     'True Negative': true_negative
# }

# %% [raw]
# # Write the row to the CSV file
# with open(csv_file, 'a', newline='') as file:
#     writer = csv.DictWriter(file, fieldnames=row.keys())
#     # Check if the file is empty, if yes, write the header row
#     if file.tell() == 0:
#         writer.writeheader()
#     writer.writerow(row)

# %%
model = LogisticRegression()

# %%
X=df[['Year']]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y=df['Status Mission'].astype(int)
type(y)
# Out:
# pandas.core.series.Series

# %%
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
model.score(X, y)
# Out:
# 0.8970622253065001

# %%
y_pred = model.predict(X)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y

# %%
error = y_pred - y
error
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4319    1
# 4320    0
# 4321    1
# 4322    0
# 4323    0
# Name: Status Mission, Length: 4323, dtype: int32

# %%
confusion_matrix(y_pred, y)
# Out:
# array([[   0,    0],
#        [ 445, 3878]], dtype=int64)

# %%
sum(error==-1)/len(error)
# Out:
# 0.0

# %%
sum(y_pred == y)/len(error)
# Out:
# 0.8970622253065001

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
sum(y_pred)
# Out:
# 4323

# %%
df[~df['Status Mission'].astype(bool)].sample(100)
# Out:
#                Company  Status Rocket  Rocket Status Mission Launch Country  \
# 629             SpaceX  StatusRetired    59.5          False            USA
# 91                Exos   StatusActive     NaN          False            USA
# 4259      US Air Force  StatusRetired     NaN          False            USA
# 3499         RVSN USSR  StatusRetired     NaN          False         Russia
# 3671         RVSN USSR  StatusRetired     NaN          False     Kazakhstan
# ...                ...            ...     ...            ...            ...
# 1145              ISRO  StatusRetired    47.0          False          India
# 3152         RVSN USSR  StatusRetired     NaN          False     Kazakhstan
# 1680  General Dynamics  StatusRetired     NaN          False            USA
# 4102  General Dynamics  StatusRetired     NaN          False            USA
# 4078         RVSN USSR  StatusRetired     NaN          False     Kazakhstan
#
#      Company Origin Ownership  Year  Month  Day   Time  Rocket_isna  \
# 629             USA         P  2012     10    8  00:35            0
# 91              USA         P  2019     10   26  17:40            1
# 4259            USA         S  1960      6   29  22:00            1
# 3499         Russia         S  1969     12   27  14:20            1
# 3671         Russia         S  1968      4   24  16:00            1
# ...             ...       ...   ...    ...  ...    ...          ...
# 1145          India         S  2001      4   18  10:13            0
# 3152         Russia         S  1973      4   25  09:10            1
# 1680            USA         P  1992      8   22  22:40            1
# 4102            USA         P  1962     12   17  20:36            1
# 4078         Russia         S  1963      7   10  10:03            1
#
#                 Launch Pad                    Facility Space Vehicle
# 629                 SLC-40          Cape Canaveral AFS        Falcon
# 91    Vertical Launch Area           Spaceport America         SARGE
# 4259       SLC-1W (75-3-4)              Vandenberg AFB     Thor-DM18
# 3499            Site 132/1         Plesetsk Cosmodrome     Cosmos-3M
# 3671            Site 90/19         Baikonur Cosmodrome    Tsyklon-2A
# ...                    ...                         ...           ...
# 1145      First Launch Pad  Satish Dhawan Space Centre          GSLV
# 3152            Site 90/19         Baikonur Cosmodrome     Tsyklon-2
# 1680               SLC-36B          Cape Canaveral AFS         Atlas
# 4102                SLC-3E              Vandenberg AFB     Atlas-LV3
# 4078              Site 1/5         Baikonur Cosmodrome      Vostok-2
#
# [100 rows x 15 columns]

# %%
df[df['Status Mission'].astype(bool)].sample(100)
# Out:
#                Company  Status Rocket  Rocket Status Mission Launch Country  \
# 3619         RVSN USSR  StatusRetired     NaN           True     Kazakhstan
# 2653         RVSN USSR  StatusRetired     NaN           True         Russia
# 1495            VKS RF  StatusRetired     NaN           True         Russia
# 2028         RVSN USSR  StatusRetired     NaN           True         Russia
# 2451              ISRO  StatusRetired     NaN           True          India
# ...                ...            ...     ...            ...            ...
# 3852  General Dynamics  StatusRetired     NaN           True            USA
# 2871         RVSN USSR  StatusRetired     NaN           True         Russia
# 3527         RVSN USSR  StatusRetired     NaN           True         Russia
# 707           Northrop   StatusActive    46.0           True            USA
# 1343            Boeing  StatusRetired     NaN           True            USA
#
#      Company Origin Ownership  Year  Month  Day   Time  Rocket_isna  \
# 3619         Russia         S  1968     11    1  00:27            1
# 2653         Russia         S  1977     10   21  10:05            1
# 1495         Russia         S  1995      8    9  01:21            1
# 2028         Russia         S  1986     12   10  07:30            1
# 2451          India         S  1980      7   18  02:33            1
# ...             ...       ...   ...    ...  ...    ...          ...
# 3852            USA         P  1966      8   16  18:30            1
# 2871         Russia         S  1975     12    3  10:00            1
# 3527         Russia         S  1969      9   24  12:15            1
# 707             USA         P  2010     11   20  01:25            0
# 1343            USA         P  1997     12   20  13:16            1
#
#       Launch Pad                    Facility Space Vehicle
# 3619  Site 90/20         Baikonur Cosmodrome    Tsyklon-2A
# 2653  Site 132/1         Plesetsk Cosmodrome     Cosmos-3M
# 1495   Site 43/3         Plesetsk Cosmodrome     Molniya-M
# 2028   Site 32/2         Plesetsk Cosmodrome     Tsyklon-3
# 2451      SLV LP  Satish Dhawan Space Centre         SLV-3
# ...          ...                         ...           ...
# 3852      SLC-4E              Vandenberg AFB    Atlas-SLV3
# 2871   Site 43/3         Plesetsk Cosmodrome       Voskhod
# 3527   Site 41/1         Plesetsk Cosmodrome       Voskhod
# 707         LP-1   Pacific Spaceport Complex      Minotaur
# 1343      SLC-2W              Vandenberg AFB         Delta
#
# [100 rows x 15 columns]
